# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_raw_data = pd.read_feather(r"C:\Users\Nick\Documents\My_project\Data_analysis\Sales_data_analysis\src\Sales_data.ftr")

# %%
df_raw_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df_raw_data = df_raw_data.dropna(how="all")

# %%
df_raw_data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df_raw_data.duplicated().sum()
# Out:
# 618

# %%
df_raw_data = df_raw_data.drop_duplicates()

# %%
df_raw_data.duplicated().sum()
# Out:
# 0

# %%
df_raw_data[df_raw_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %% [markdown]
# ## Best Month of the sale

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
def months(x):
    return x.split('/')[0]

# %%
df_raw_data['Months'] = df_raw_data["Order Date"].apply(months)

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     04

# %%
df_raw_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Months              object
# dtype: object

# %%
filter1 = df_raw_data['Months'] == "Order Date"

# %%
df_raw_data = df_raw_data[~filter1]

# %%
df_raw_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Months              object
# dtype: object

# %%
df_raw_data["Months"] = df_raw_data["Months"].astype(int)

# %%
df_raw_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Months               int32
# dtype: object

# %%
df_raw_data["Quantity Ordered"] = df_raw_data["Quantity Ordered"].astype(int)

# %%
df_raw_data["Price Each"] = df_raw_data["Price Each"].astype(float)

# %%
df_raw_data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Months                int32
# dtype: object

# %%
df_raw_data["sales"] = df_raw_data["Quantity Ordered"] * df_raw_data["Price Each"]

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99

# %%
df_raw_data.groupby(["Months"])["sales"].sum()
# Out:
# Months
# 1     1821413.16
# 2     2200078.08
# 3     2804973.35
# 4     3389217.98
# 5     3150616.23
# 6     2576280.15
# 7     2646461.32
# 8     2241083.37
# 9     2094465.69
# 10    3734777.86
# 11    3197875.05
# 12    4608295.70
# Name: sales, dtype: float64

# %%
df_raw_data.groupby(["Months"])["sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Months'>

# %% [markdown]
# ## Conclusion --> December has the highest sales. 2nd Highest sales is on October. 3rd is on April

# %% [markdown]
# ## Finding out the maximum sales/Order in the City

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99

# %% [markdown]
# ### Method-1

# %%
df_raw_data["Purchase Address"][0].split(",")[1]
# Out:
# ' Dallas'

# %%
def cities(y):
    return y.split(",")[1]

# %%
df_raw_data["Cities"] = df_raw_data["Purchase Address"].apply(cities)

# %%
df_raw_data.groupby(["Cities"])["sales"].sum().plot(kind="pie", autopct="%1.0f%%")
# Out:
# <Axes: ylabel='sales'>

# %% [markdown]
# ### Method - 2

# %%
df_raw_data["Cities"] = df_raw_data["Purchase Address"].str.split(",").str.get(1)

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99
#
#          Cities
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
df_raw_data.value_counts("Cities")
# Out:
# Cities
#  San Francisco    44662
#  Los Angeles      29564
#  New York City    24847
#  Boston           19901
#  Atlanta          14863
#  Dallas           14797
#  Seattle          14713
#  Portland         12449
#  Austin            9890
# Name: count, dtype: int64

# %%
df_raw_data.value_counts("Cities").plot(kind="pie", autopct = "%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Conclusion --> Top 3 sales/Order Cities are San Francisco, Los Angeles, New York City. Also approx. 50% of the sales from the above cities

# %% [markdown]
# ## Most product sold & Why?

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99
#
#          Cities
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
freq = df_raw_data.groupby(["Product"]).agg({"Quantity Ordered":"sum","Price Each":"mean"})

# %%
freq = freq.reset_index()

# %%
freq
# Out:
#                        Product  Quantity Ordered  Price Each
# 0                 20in Monitor              4126      109.99
# 1       27in 4K Gaming Monitor              6239      389.99
# 2             27in FHD Monitor              7541      149.99
# 3       34in Ultrawide Monitor              6192      379.99
# 4        AA Batteries (4-pack)             27615        3.84
# 5       AAA Batteries (4-pack)             30986        2.99
# 6     Apple Airpods Headphones             15637      150.00
# 7   Bose SoundSport Headphones             13430       99.99
# 8                Flatscreen TV              4813      300.00
# 9                 Google Phone              5529      600.00
# 10                    LG Dryer               646      600.00
# 11          LG Washing Machine               666      600.00
# 12    Lightning Charging Cable             23169       14.95
# 13          Macbook Pro Laptop              4725     1700.00
# ...

# %%
fig1,ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(freq["Product"], freq["Quantity Ordered"], color="r")
ax2.plot(freq["Product"], freq["Price Each"])
a = freq["Product"].values
ax1.set_xticklabels(a,rotation = "vertical")
# Out:
# C:\Users\Nick\AppData\Local\Temp\ipykernel_38112\1579806543.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(a,rotation = "vertical")
# [Text(0, 0, '20in Monitor'),
#  Text(1, 0, '27in 4K Gaming Monitor'),
#  Text(2, 0, '27in FHD Monitor'),
#  Text(3, 0, '34in Ultrawide Monitor'),
#  Text(4, 0, 'AA Batteries (4-pack)'),
#  Text(5, 0, 'AAA Batteries (4-pack)'),
#  Text(6, 0, 'Apple Airpods Headphones'),
#  Text(7, 0, 'Bose SoundSport Headphones'),
#  Text(8, 0, 'Flatscreen TV'),
#  Text(9, 0, 'Google Phone'),
#  Text(10, 0, 'LG Dryer'),
#  Text(11, 0, 'LG Washing Machine'),
#  Text(12, 0, 'Lightning Charging Cable'),
#  Text(13, 0, 'Macbook Pro Laptop'),
#  Text(14, 0, 'ThinkPad Laptop'),
#  Text(15, 0, 'USB-C Charging Cable'),
#  Text(16, 0, 'Vareebadd Phone'),
#  Text(17, 0, 'Wired Headphones'),
#  Text(18, 0, 'iPhone')]

# %% [markdown]
# ## Conclusion--> By the above graph we can analyze that the higher prices items are sold less and lesser price items are sold more.
# ### For reference:In the Graph, Line graph represents "Price" & Bar graph represents "quantities ordered".

# %% [markdown]
# ## Trend of the sales of the product

# %%
df_raw_data["Product"].value_counts()[0:5].index
# Out:
# Index(['USB-C Charging Cable', 'Lightning Charging Cable',
#        'AAA Batteries (4-pack)', 'AA Batteries (4-pack)', 'Wired Headphones'],
#       dtype='object', name='Product')

# %%
most_sold_product = df_raw_data["Product"].value_counts()[0:5].index

# %%
df_most_sold_product =  df_raw_data[df_raw_data["Product"].isin(most_sold_product)]

# %%
df_most_sold_product.head(5)
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   176558  USB-C Charging Cable                 2       11.95
# 4   176560      Wired Headphones                 1       11.99
# 5   176561      Wired Headphones                 1       11.99
# 6   176562  USB-C Charging Cable                 1       11.95
# 8   176564  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Months  sales  \
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001       4  23.90
# 4  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001       4  11.99
# 5  04/30/19 09:27       333 8th St, Los Angeles, CA 90001       4  11.99
# 6  04/29/19 13:03  381 Wilson St, San Francisco, CA 94016       4  11.95
# 8  04/12/19 10:58         790 Ridge St, Atlanta, GA 30301       4  11.95
#
#            Cities
# 0          Dallas
# 4     Los Angeles
# 5     Los Angeles
# 6   San Francisco
# 8         Atlanta

# %%
pivot = df_most_sold_product.groupby(["Months","Product"]).size().unstack()

# %%
pivot
# Out:
# Product  AA Batteries (4-pack)  AAA Batteries (4-pack)  \
# Months
# 1                         1037                    1084
# 2                         1274                    1320
# 3                         1672                    1645
# 4                         2062                    1988
# 5                         1821                    1888
# 6                         1540                    1451
# 7                         1555                    1554
# 8                         1357                    1340
# 9                         1314                    1281
# 10                        2240                    2234
# 11                        1970                    1999
# 12                        2716                    2828
#
# Product  Lightning Charging Cable  USB-C Charging Cable  Wired Headphones
# Months
# 1                            1069                  1171              1004
# 2                            1393                  1511              1179
# ...

# %%
pivot.plot(figsize=(8,8))
# Out:
# <Axes: xlabel='Months'>

# %% [markdown]
# ## Conclusion--> USB-C Charging cable most sold on December, Lightning charging cable most sold on March by this business stack holders can make decisions & plans.

# %% [markdown]
# ## What product are most often sold together?

# %%
df_raw_data.head(5)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99
#
#          Cities
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
df_duplicated = df_raw_data[df_raw_data["Order ID"].duplicated(keep=False)]

# %%
df_duplicated
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Months  \
# ...

# %%
dup_products = df_duplicated.groupby(["Order ID"])["Product"].apply(lambda x:",".join(x)).reset_index().rename(columns={'Product':'grouped_products'})

# %%
dup_products
# Out:
#      Order ID                                 grouped_products
# 0      141275            USB-C Charging Cable,Wired Headphones
# 1      141290   Apple Airpods Headphones,AA Batteries (4-pack)
# 2      141365                 Vareebadd Phone,Wired Headphones
# 3      141384                Google Phone,USB-C Charging Cable
# 4      141450          Google Phone,Bose SoundSport Headphones
# ...       ...                                              ...
# 6874   319536              Macbook Pro Laptop,Wired Headphones
# 6875   319556                    Google Phone,Wired Headphones
# 6876   319584                          iPhone,Wired Headphones
# 6877   319596                  iPhone,Lightning Charging Cable
# 6878   319631  34in Ultrawide Monitor,Lightning Charging Cable
#
# [6879 rows x 2 columns]

# %%
df_products = df_duplicated.merge(dup_products, how="left", on="Order ID")

# %%
df_products
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       176560            Google Phone                 1      600.00
# 1       176560        Wired Headphones                 1       11.99
# 2       176574            Google Phone                 1      600.00
# 3       176574    USB-C Charging Cable                 1       11.95
# 4       176586  AAA Batteries (4-pack)                 2        2.99
# ...        ...                     ...               ...         ...
# 14123   259303   AA Batteries (4-pack)                 1        3.84
# 14124   259314        Wired Headphones                 1       11.99
# 14125   259314  AAA Batteries (4-pack)                 2        2.99
# 14126   259350            Google Phone                 1      600.00
# 14127   259350    USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Months   sales  \
# ...

# %%
df_products = df_products.drop_duplicates(subset=["Order ID"])

# %%
df_products
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       176560              Google Phone                 1      600.00
# 2       176574              Google Phone                 1      600.00
# 4       176586    AAA Batteries (4-pack)                 2        2.99
# 6       176672  Lightning Charging Cable                 1       14.95
# 8       176681  Apple Airpods Headphones                 1      150.00
# ...        ...                       ...               ...         ...
# 14118   259277                    iPhone                 1      700.00
# 14120   259297                    iPhone                 1      700.00
# 14122   259303    34in Ultrawide Monitor                 1      379.99
# 14124   259314          Wired Headphones                 1       11.99
# 14126   259350              Google Phone                 1      600.00
#
#            Order Date                        Purchase Address  Months   sales  \
# ...

# %%
df_products["grouped_products"].value_counts()[0:5].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Conclusion --> By this we can plan the recommended offers with respectively.
